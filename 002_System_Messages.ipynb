# %%
import boto3

# %%
client = boto3.client("bedrock-runtime", region_name="eu-central-1")
model_id = "eu.anthropic.claude-sonnet-4-5-20250929-v1:0"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": [{"text": text}]}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": [{"text": text}]}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0):
    params = {
        "modelId": model_id,
        "messages": messages,
        "inferenceConfig": { "temperature": temperature},
    }

    if system:
        params["system"] = [{"text": system}]

    response = client.converse(**params)

    return response["output"]["message"]["content"][0]["text"]

# %%
messages = []

add_user_message(messages, "Generate a movie idea in one sentence.")
text = chat(messages, temperature=0.0)

print(text)
# Out:
# A retired astronaut discovers her dreams are actually memories from a parallel universe where she never came home, and now both versions of her life are colliding.

# %%
messages = []

add_user_message(messages, "Write a function that checks a string for duplicate characters")
text = chat(messages, system="You are a Python specialist. Your job is to write functions without any titles or explanations, just pure code")

print(text)
# Out:
# ```python
# def has_duplicate_characters(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# ```python
# def has_duplicate_characters(s: str, case_sensitive: bool = True) -> bool:
#     if not case_sensitive:
#         s = s.lower()
#     return len(s) != len(set(s))
# ```
#
# ```python
# def find_duplicate_characters(s: str) -> set:
#     seen = set()
#     duplicates = set()
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#     return duplicates
# ```
#
# ```python
# def count_duplicate_characters(s: str) -> dict:
#     char_count = {}
#     for char in s:
#         char_count[char] = char_count.get(char, 0) + 1
#     return {char: count for char, count in char_count.items() if count > 1}
# ```
